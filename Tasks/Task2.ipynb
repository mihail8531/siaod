# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
def task1(x: list[int]) -> list[int]:
    sorted_x = sorted(x, reverse=True)
    for i in range(len(x) - 2):
        if sorted_x[i] < sum(sorted_x[i + 1:i + 3]):
            return sorted_x[i:i + 3]
    return 0

print(*task1([2, 5, 3, 10, 2]))
[10, 5, 3, 2, 2]
# Out:
# [3, 2, 2]

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
def task2(nums: list[int]) -> str:
    return ''.join(sorted(map(str, nums), reverse=True))
print(task2([123, 1, 5]))
# Out:
# 51231

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %%
from random import randint
from functools import partial

def gen_matrix(n: int=5, m: int=8,
               min_value: int=-100, max_value: int=100) -> list[list[int]]:
    return [[randint(min_value, max_value) for j in range(n)] for i in range(m)]

def task3(x: list[list[int]]) -> list[list[int]]:
    n = len(x)
    m = len(x[0])
    d = [[None] * (n - i - 1) + x[i] + [None] * i for i in range(n)]
    d = list(map(list, zip(*d)))
    d_len = n + m - 1
    d_max = n
    for i in range(d_len):
        l = max(d_max - i - 1, 0)
        r = max(d_max - d_len + i, 0)
        d[i] = [None] * l + sorted(d[i][l:n - r]) + [None] * r
    return [list(l) for l in map(partial(filter, lambda x: x is not None), zip(*d))]

# Вывод
def matrix_int2str(matrix: list[list[int]]) -> list[list[str]]:
    return [list(map(str, l)) for l in matrix]

def matrix_str2nice(matrix: list[list[str]], max_len: int) -> str:
    return '\n'.join(','.join(map(lambda x: ' ' * (max_len - len(x)) + x, l))
                     for l in matrix)
matrix = gen_matrix()
matrix_str = matrix_int2str(matrix)
max_num_len = max(max(map(len, l)) for l in matrix_str)
nice_matrix = matrix_str2nice(matrix_str, max_num_len)
nice_res_matrix = matrix_str2nice(matrix_int2str(task3(matrix)), max_num_len)
print(nice_matrix, end='\n\n')
print(nice_res_matrix)
# Out:
# [None, None, None, None, None, None, None, 27]
# [None, None, None, None, None, None, -62, -48]
# [None, None, None, None, None, -87, -59, 52]
# [None, None, None, None, 52, 50, 71, -46]
# [None, None, None, -82, 17, -99, -68, -18]
# [None, None, 84, 99, -96, -30, 94, None]
# [None, -63, -100, 77, 1, 17, None, None]
# [-51, -19, 57, -83, 38, None, None, None]
# [62, -65, 10, 59, None, None, None, None]
# [14, 37, -30, None, None, None, None, None]
# [81, 13, None, None, None, None, None, None]
# [56, None, None, None, None, None, None, None]
#  -51,  62,  14,  81,  56
#  -63, -19, -65,  37,  13
#   84,-100,  57,  10, -30
#  -82,  99,  77, -83,  59
#   52,  17, -96,   1,  38
#  -87,  50, -99, -30,  17
#  -62, -59,  71, -68,  94
#   27, -48,  52, -46, -18
#
#  -83, -65, -30,  13,  56
# -100, -51,  10,  14,  81
#  -96, -63, -19,  59,  37
#  -99, -30,   1,  38,  62
#  -46, -82,  84,  17,  57
#  -87,  50, -68,  94,  77
#  -62, -59,  52, -18,  99
#   27, -48,  52,  71,  17
