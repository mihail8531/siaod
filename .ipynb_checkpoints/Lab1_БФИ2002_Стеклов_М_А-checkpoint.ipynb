# %% [markdown]
# ### Лабораторная работа №1
# ## Выполнил студент группы БФИ2002 Стеклов М. А.

# %% [markdown]
# ### Задание №1
# Вывести hello world

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц

# %%
import random
from typing import List
def generate_matrix(m=50, n=50,
                    min_limit=-250, max_limit=1023) -> List[List[float]]:
    return [[random.randint(min_limit, max_limit) for j in range(n)] for i in range(m)]

# %% [markdown]
# ### Задание №3
# Реализовать различные сортировки:
# 1. Выбором
# 2. Вствкой
# 3. Обменом
# 4. Шелла
# 5. Турнирная
# 6. Быстрая сортировка
# 7. Пирамидальная

# %%
# 1. Сортировка выбором
def selection_sort(x: List[float]) -> List[float]:
    n = len(x)
    if n < 2:
        return x
    for i in range(n - 1):
        m, m_i = x[i], i
        for j in range(i + 1, n):
            if x[j] < m:
                m, m_i = x[j], j
        x[i], x[m_i] = x[m_i], x[i]
    return x

# %%
# 2. Сортировка вставкой
def insertion_sort(x: List[float]) -> List[float]:
    n = len(x)
    if n < 2:
        return x
    for i in range(1, n):
        insrt_i = 0
        for j in range(i - 1, -1, -1):
            if x[i] > x[j]:
                insrt_i = j + 1
                break
        x.insert(insrt_i, x.pop(i))
    return x

# %%
# 3. Сортировка обменом
def bubble_sort(x: List[float]) -> List[float]:
    n = len(x)
    if n < 2:
        return x
    for i in range(n - 1):
        for j in range(0, n - 1 - i):
            if x[j] >= x[j + 1]:
                x[j], x[j + 1] = x[j + 1], x[j]
    return x

# %%
# 4. Сортировка Шелла
def shell_sort(x: List[float]) -> List[float]:
    n = len(x)
    if n < 2:
        return x
    ds = [k for k in [1750, 701, 301, 132, 57, 23, 10, 4, 1] if k < n // 2] # A102549
    for d in ds:
        for i in range(d):
            for j in range(i + d, n, d):
                insrt_i = i
                for k in range(j - d, i - d, -d):
                    if x[j] > x[k]:
                        insrt_i = k + d
                        break
                x.insert(insrt_i, x.pop(j))
    return x

# %%
import math

# %%
#5. Турнирная сортировка
def min_heapify(x: List[float], n: int, i: int):
    p_i = i
    l_i = p_i * 2 + 1
    r_i = l_i + 1
    if l_i < n and x[l_i] < x[p_i]:
        p_i = l_i
    if r_i < n and x[r_i] < x[p_i]:
        p_i = r_i
    if p_i != i:
        x[p_i], x[i] = x[i], x[p_i]
        min_heapify(x, n, p_i)

# %%
def fill_tournament(x: List[float], n:int, tournament: List[float],
                    leafs: int, i: int, losers: List[float], winners: List[float]) -> int:
    for j in range(-leafs, 0, 1):
        if math.isinf(tournament[j]):
            if len(winners) > 0 and x[i] < winners[-1]:
                losers.append(x[i])
            else:
                tournament[j] = x[i]
            i += 1
        if i >= n:
            return i
    return i

# %%
def merge(x: List[float], y: List[float]) -> List[float]:
    res = []
    i, j = 0, 0
    while i < len(x) and j < len(y):
        if x[i] < y[j]:
            res.append(x[i])
            i += 1
        else:
            res.append(y[j])
            j += 1
    return res + x[i:] + y[j:]

# %%
def tournament_sort(x: List[float], layers=3) -> List[float]:
    n = len(x)
    if n < 2:
        return x
    losers, winners = [], []
    leafs = 2 ** (layers - 1)
    tournament_list = [math.inf] * (2 ** layers - 1)
    j = fill_tournament(x, n, tournament_list, leafs, 0, losers, winners)
    for i in range(n // 2 + 1, -1, -1):
        min_heapify(tournament_list, len(tournament_list), i)
    while (len(losers) + len(winners) < n):
        if (j < n):
            j = fill_tournament(x, n, tournament_list, leafs, j, losers, winners)
        for i in range(n // 2 + 1, -1, -1):
            min_heapify(tournament_list, len(tournament_list), i)
        winners.append(tournament_list[0])
        tournament_list[0] = math.inf
    print(losers)
    print(winners)
    x = losers + winners
    if len(losers) > 0:
        # x = tournament_sort(x)
        losers = tournament_sort(losers)
        x = merge(losers, winners)
    return x

# %%
x = [random.randint(-100, 100) for i in range(30)]
s_s = selection_sort(x[:])
t_s = tournament_sort(x[:])
print(s_s == t_s)
print(s_s)
print(t_s)
# Out:
# [-100, -40, -89, -40, -7, -93, 35, -7, -21, 34, -57, 48, 41, -70, 42]
# [-13, -6, 17, 21, 37, 42, 52, 52, 69, 64, 64, 77, 79, 93, 95]
# [-57, -70]
# [-100, -93, -89, -40, -40, -21, -7, -7, 34, 35, 41, 42, 48]
# []
# [-70, -57]
# False
# [-100, -93, -89, -70, -57, -40, -40, -21, -13, -7, -7, -6, 17, 21, 34, 35, 37, 41, 42, 42, 48, 52, 52, 64, 64, 69, 77, 79, 93, 95]
# [-100, -93, -89, -70, -57, -40, -40, -21, -13, -7, -7, -6, 17, 21, 34, 35, 37, 41, 42, 42, 48, 52, 52, 69, 64, 64, 77, 79, 93, 95]

# %%
# 6.Быстрая сортировка
def quick_sort(x: List[float]) -> List[float]:
    n = len(x)
    if (n < 2):
        return x
    l, m, r = [], [], []
    for i in range(0, n):
        if x[i] < x[0]:
            l.append(x[i])
        elif x[i] == x[0]:
            m.append(x[i])
        else:
            r.append(x[i])
    return quick_sort(l) + m + quick_sort(r)

# %%
#7 Пирамидальная сортировка
def max_heapify(x: List[float], n:int, i:float):
    p_i = i
    l_i = p_i * 2 + 1
    r_i = l_i + 1
    if l_i < n and x[l_i] > x[p_i]:
        p_i = l_i
    if r_i < n and x[r_i] > x[p_i]:
        p_i = r_i
    if p_i != i:
        x[p_i], x[i] = x[i], x[p_i]
        max_heapify(x, n, p_i)

# %%
def heap_sort(x: List[float]) -> List[float]:
    n = len(x)
    if (n < 2):
        return x
    for i in range(n // 2 + 1, -1, -1):
        max_heapify(x, n, i)
    for i in range(n - 1, 0, -1):
        x[0], x[i] = x[i], x[0]
        max_heapify(x, i, 0)
    return x

# %%
from typing import Callable
from copy import deepcopy
x = generate_matrix()
def test(x: List[List[float]],
         sort_func: Callable[[List[float]], List[float]]) -> List[List[float]]:
    return list(map(sort_func, x))

# %%
#%%time
#%%timeit -n 1000
# Тест сортировки выбором
test(deepcopy(x), selection_sort)
# Out:
# 3.43 ms ± 221 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 23.9 s, sys: 116 ms, total: 24 s
# Wall time: 24 s

# %%
#%%time
#%%timeit -n 1000
# Тест сортировки вставками
test(deepcopy(x), insertion_sort)
# Out:
# 1.16 ms ± 28.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 8.11 s, sys: 8.06 ms, total: 8.12 s
# Wall time: 8.13 s

# %%
# %%time
# %%timeit -n 1000
# Тест сортировки обменом
test(deepcopy(x), bubble_sort)
# Out:
# 5.4 ms ± 293 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 37.7 s, sys: 23.9 ms, total: 37.7 s
# Wall time: 37.8 s

# %%
# %%time
# %%timeit -n 1000
# Тест сортировки шелла
test(deepcopy(x), shell_sort)
# Out:
# 5.07 ms ± 443 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 35.4 s, sys: 19.9 ms, total: 35.4 s
# Wall time: 35.5 s

# %%
# %%time
# %%timeit -n 1000
# Тест турнирной сортировки
test(deepcopy(x), tournament_sort)
# Out:
# 28 ms ± 1.5 ms per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 3min 15s, sys: 64 ms, total: 3min 15s
# Wall time: 3min 15s

# %%
# %%time
# %%timeit -n 1000
# Тест быстрой сортировки
test(deepcopy(x), quick_sort)
# Out:
# 14.5 ms ± 253 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 1min 41s, sys: 12 ms, total: 1min 41s
# Wall time: 1min 41s

# %%
# %%time
# %%timeit -n 1000
# Тест пирамидальной сортировки
test(deepcopy(x), heap_sort)
# Out:
# 6.93 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 48.4 s, sys: 20 ms, total: 48.4 s
# Wall time: 48.5 s

# %%
# %%time
# %%timeit -n 1000
# Тест стандартной сортировки
test(deepcopy(x), sorted)
# Out:
# 32.1 µs ± 10 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# CPU times: user 224 ms, sys: 3.99 ms, total: 228 ms
# Wall time: 227 ms

# %%
selection_res = test(deepcopy(x), selection_sort)
insertion_res = test(deepcopy(x), insertion_sort)
bubble_res = test(deepcopy(x), bubble_sort)
shell_res = test(deepcopy(x), shell_sort)
tournament_res = test(deepcopy(x), tournament_sort)
quick_res = test(deepcopy(x), quick_sort)
heap_res = test(deepcopy(x), heap_sort)
std_res = test(deepcopy(x), sorted)
print(
    selection_res == std_res,
    insertion_res == std_res,
    bubble_res == std_res,
    shell_res == std_res,
    tournament_res == std_res,
    quick_res == std_res,
    heap_res == std_res)
print(tournament_res)
# Out:
# True True True True False True True
# [[-234, -213, -209, -202, -200, -192, -133, -121, -83, -35, -27, -22, 3, 47, 123, 125, 132, 139, 166, 183, 207, 254, 292, 342, 352, 388, 400, 405, 410, 416, 417, 431, 510, 539, 669, 670, 670, 670, 682, 708, 728, 754, 821, 860, 902, 902, 905, 941, 961, inf, inf, inf], [-197, -159, -137, -132, -126, -123, -122, -105, -99, -97, -88, -10, -8, 9, 29, 46, 58, 195, 203, 222, 226, 238, 243, 247, 281, 299, 312, 360, 412, 436, 465, 495, 556, 568, 597, 612, 630, 642, 644, 741, 754, 820, 865, 872, 886, 905, 961, 969, 986, 999, inf, inf, inf, inf], [-220, -219, -179, -165, -163, -133, -97, -94, -88, -78, -35, -24, -13, -13, 46, 59, 81, 106, 178, 180, 196, 207, 215, 297, 344, 384, 386, 386, 405, 441, 469, 470, 559, 567, 570, 590, 676, 694, 705, 724, 745, 770, 776, 785, 812, 869, 927, 947, 973, 1023, inf, inf, inf, inf], [-246, -227, -209, -197, -192, -187, -155, -115, -53, 37, 39, 72, 160, 196, 204, 229, 253, 264, 289, 291, 316, 387, 405, 407, 442, 537, 588, 590, 602, 606, 607, 613, 682, 700, 723, 794, 825, 837, 904, 922, 949, 961, 962, 972, inf, inf, inf, inf, inf, inf, inf], [-241, -230, -199, -176, -135, -128, -86, -79, -63, -54, -54, -36, -5, 0, 5, 28, 59, 79, 187, 201, 202, 213, 219, 417, 429, 505, 566, 629, 641, 650, 686, 691, 703, 718, 747, 765, 794, 854, 858, 863, 874, 908, 917, 973, 976, 1004, inf, inf, inf, inf, inf, inf], [-178, -169, -136, -130, -101, -80, -62, -37, -17, -15, 14, 57, 62, 76, 127, 135, 147, 149, 159, 160, 174, 207, 233, 268, 296, 327, 359, 370, 384, 401, 469, 508, 544, 570, 605, 637, 653, 683, 690, 691, 770, 822, 827, 833, 