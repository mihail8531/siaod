# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БФИ2002 Стеклов М. А.

# %% [markdown]
# ### Задание №1
# Вывести hello world

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц

# %%
import random
def generate_matrix(m=50, n=50, min_limit=-250, max_limit=1023):
    return [[random.randint(min_limit, max_limit) for j in range(n)] for i in range(m)]

# %% [markdown]
# ### Задание №3
# Реализовать различные сортировки:
# 1. Выбором
# 2. Вствкой
# 3. Обменом
# 4. Шелла
# 5. Турнирная
# 6. Быстрая сортировка
# 7. Пирамидальная

# %%
from typing import List
# 1. Сортировка выбором
def selection_sort(x:List[float]) -> List[float]:
    n = len(x)
    for i in range(n - 1):
        m, m_i = x[i], i
        for j in range(i + 1, n):
            if x[j] < m:
                m, m_i = x[j], j
        x[i], x[m_i] = x[m_i], x[i]
    return x

# %%
# 2. Сортировка вставкой
def insertion_sort(x:List[float]) -> List[float]:
    n = len(x)
    for i in range(min(1, n-1), n):
        k = x[i]
        j = 0
        while j <= i:
            if k <= x[j]:
                x.insert(j, k)
                break
            j += 1
        x.pop(i + 1)
    return x
#x = [random.randint(-100, 100) for i in range(20)]
#s_s = selection_sort(x.copy())
#i_s = insertion_sort(x.copy())
#print(s_s)
#print(i_s)
#print(all(map(lambda k: k[0] == k[1], zip(s_s,i_s))))
# Out:
# [-23, -89, 28, 11, -1, -26, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -23, 28, 11, -1, -26, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -23, 28, 11, -1, -26, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -23, 11, 28, -1, -26, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -23, -1, 11, 28, -26, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -26, -23, -1, 11, 28, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -26, -23, -1, 11, 28, 36, -37, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -26, -23, -1, 11, 28, 36, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -26, -23, -1, 11, 28, 36, 89, -35, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -35, -26, -23, -1, 11, 28, 36, 89, 82, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -35, -26, -23, -1, 11, 28, 36, 82, 89, -2, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -35, -26, -23, -2, -1, 11, 28, 36, 82, 89, 78, -91, -76, 93, 53, -79, -59, 28]
# [-89, -37, -35, -26, -23, -2, -1, 11, 28, 36, 78, 82, 89, -91, -76, 93, 53, -79, -59, 28]
# [-91, -89, -37, -35, -26, -23, -2, -1, 11, 28, 36, 78, 82, 89, -76, 93, 53, -79, -59, 28]
# [-91, -89, -76, -37, -35, -26, -23, -2, -1, 11, 28, 36, 78, 82, 89, 93, 53, -79, -59, 28]
# [-91, -89, -76, -37, -35, -26, -23, -2, -1, 11, 28, 36, 78, 82, 89, 93, 53, -79, -59, 28]
# [-91, -89, -76, -37, -35, -26, -23, -2, -1, 11, 28, 36, 53, 78, 82, 89, 93, -79, -59, 28]
# [-91, -89, -79, -76, -37, -35, -26, -23, -2, -1, 11, 28, 36, 53, 78, 82, 89, 93, -59, 28]
# [-91, -89, -79, -76, -59, -37, -35, -26, -23, -2, -1, 11, 28, 36, 53, 78, 82, 89, 93, 28]
# [-91, -89, -79, -76, -59, -37, -35, -26, -23, -2, -1, 11, 28, 28, 36, 53, 78, 82, 89, 93]
# [-91, -89, -79, -76, -59, -37, -35, -26, -23, -2, -1, 11, 28, 28, 36, 53, 78, 82, 89, 93]
# True

# %%
# 3. Сортировка обменом
def bubble_sort(x:List[float]) -> List[float]:
    n = len(x)
    for i in range(n - 1):
        for j in range(0, n - 1 - i):
            if x[j] >= x[j + 1]:
                x[j], x[j + 1] = x[j + 1], x[j]
    return x
# Out:
# [-97, -95, -83, -61, -41, -20, -18, -15, -10, -5, -4, 2, 14, 29, 32, 36, 44, 74, 78, 80]
# True

# %%
# 4. Сортировка Шелла
def shell_sort(x:List[float]) -> List[float]:
    n = len(x)
    ds = [k for k in [1750, 701, 301, 132, 57, 23, 10, 4, 1] if k < n] # A102549
    for d in ds:
        for i in range(d):
            pass
            #for j in range(i, ):

# %%
# 5.Турнирная сортировка 
def tournament_sort(x:List[float]) -> List[float]:
    pass

# %%
# 6.Быстрая сортировка
def quick_sort(x:List[float]) -> List[float]:
    n = len(x)
    if (n < 2):
        return x
    l, m, r = [], [], []
    for i in range(0, n):
        if x[i] < x[0]:
            l.append(x[i])
        elif x[i] == x[0]:
            m.append(x[i])
        else:
            r.append(x[i])
    return quick_sort(l) + m + quick_sort(r)

x = [random.randint(-100, 100) for i in range(20)]
s_s = selection_sort(x.copy())
q_s = quick_sort(x.copy())
print(q_s)
print(all(map(lambda k: k[0] == k[1], zip(s_s, q_s))))
